# %% [markdown]
# <a href="https://colab.research.google.com/github/KaGuYA31/Tugas_Machine-Learning/blob/main/Traffic_Predicton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5e7429e9-6ac9-4c47-a58d-24f7941adca3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e7429e9-6ac9-4c47-a58d-24f7941adca3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving traffic.csv to traffic.csv

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras import callbacks
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Loading Data
data = pd.read_csv("traffic.csv")
data.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041

# %%
data["DateTime"]= pd.to_datetime(data["DateTime"])
data = data.drop(["ID"], axis=1) #dropping IDs
data.info()

# %%
#df to be used for EDA
df=data.copy() 
#Let's plot the Timeseries
colors = [ "#FFD4DB","#BBE7FE","#D3B5E5","#dfe2b6"]
plt.figure(figsize=(20,4),facecolor="#627D78")
Time_series=sns.lineplot(x=df['DateTime'],y="Vehicles",data=df, hue="Junction", palette=colors)
Time_series.set_title("Traffic On Junctions Over Years")
Time_series.set_ylabel("Number of Vehicles")
Time_series.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
#Exploring more features 
df["Year"]= df['DateTime'].dt.year
df["Month"]= df['DateTime'].dt.month
df["Date_no"]= df['DateTime'].dt.day
df["Hour"]= df['DateTime'].dt.hour
df["Day"]= df.DateTime.dt.strftime("%A")
df.head()
# Out:
#              DateTime  Junction  Vehicles  Year  Month  Date_no  Hour     Day
# 0 2015-11-01 00:00:00         1        15  2015     11        1     0  Sunday
# 1 2015-11-01 01:00:00         1        13  2015     11        1     1  Sunday
# 2 2015-11-01 02:00:00         1        10  2015     11        1     2  Sunday
# 3 2015-11-01 03:00:00         1         7  2015     11        1     3  Sunday
# 4 2015-11-01 04:00:00         1         9  2015     11        1     4  Sunday

# %%
#Let's plot the Timeseries
new_features = [ "Year","Month", "Date_no", "Hour", "Day"]

for i in new_features:
    plt.figure(figsize=(10,2),facecolor="#627D78")
    ax=sns.lineplot(x=df[i],y="Vehicles",data=df, hue="Junction", palette=colors )
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(12,5),facecolor="#627D78")
count = sns.countplot(data=df, x =df["Year"], hue="Junction", palette=colors)
count.set_title("Count Of Traffic On Junctions Over Years")
count.set_ylabel("Number of Vehicles")
count.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
corrmat = df.corr()
plt.subplots(figsize=(10,10),facecolor="#627D78")
sns.heatmap(corrmat,cmap= "Pastel2",annot=True,square=True, )

# %%
sns.pairplot(data=df, hue= "Junction",palette=colors)

# %%
#Pivoting data fron junction 
df_J = data.pivot(columns="Junction", index="DateTime")
df_J.describe()
# Out:
#               Vehicles
# Junction             1             2             3            4
# count     14592.000000  14592.000000  14592.000000  4344.000000
# mean         45.052906     14.253221     13.694010     7.251611
# std          23.008345      7.401307     10.436005     3.521455
# min           5.000000      1.000000      1.000000     1.000000
# 25%          27.000000      9.000000      7.000000     5.000000
# 50%          40.000000     13.000000     11.000000     7.000000
# 75%          59.000000     17.000000     18.000000     9.000000
# max         156.000000     48.000000    180.000000    36.000000

# %%
#Creating new sets
df_1 = df_J[[('Vehicles', 1)]]
df_2 = df_J[[('Vehicles', 2)]]
df_3 = df_J[[('Vehicles', 3)]]
df_4 = df_J[[('Vehicles', 4)]]
df_4 = df_4.dropna() #Junction 4 has limited data only for a few months

#Dropping level one in dfs's index as it is a multi index data frame
list_dfs = [df_1, df_2, df_3, df_4]
for i in list_dfs:
    i.columns= i.columns.droplevel(level=1)   

#Function to plot comparitive plots of dataframes
def Sub_Plots4(df_1, df_2,df_3,df_4,title):
    fig, axes = plt.subplots(4, 1, figsize=(15, 8),facecolor="#627D78", sharey=True)
    fig.suptitle(title)
    #J1
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[0])
    #pl_1=plt.ylabel()
    axes[0].set(ylabel ="Junction 1")
    #J2
    pl_2=sns.lineplot(ax=axes[1],data=df_2,color=colors[1])
    axes[1].set(ylabel ="Junction 2")
    #J3
    pl_3=sns.lineplot(ax=axes[2],data=df_3,color=colors[2])
    axes[2].set(ylabel ="Junction 3")
    #J4
    pl_4=sns.lineplot(ax=axes[3],data=df_4,color=colors[3])
    axes[3].set(ylabel ="Junction 4")
    
    
#Plotting the dataframe to check for stationarity
Sub_Plots4(df_1.Vehicles, df_2.Vehicles,df_3.Vehicles,df_4.Vehicles,"Dataframes Before Transformation")

# %%
# Normalize Function
def Normalize(df,col):
    average = df[col].mean()
    stdev = df[col].std()
    df_normalized = (df[col] - average) / stdev
    df_normalized = df_normalized.to_frame()
    return df_normalized, average, stdev

# Differencing Function
def Difference(df,col, interval):
    diff = []
    for i in range(interval, len(df)):
        value = df[col][i] - df[col][i - interval]
        diff.append(value)
    return diff

# %%
#Normalizing and Differencing to make the series stationary 
df_N1, av_J1, std_J1 = Normalize(df_1, "Vehicles")
Diff_1 = Difference(df_N1, col="Vehicles", interval=(24*7)) #taking a week's diffrence
df_N1 = df_N1[24*7:]
df_N1.columns = ["Norm"]
df_N1["Diff"]= Diff_1

df_N2, av_J2, std_J2 = Normalize(df_2, "Vehicles")
Diff_2 = Difference(df_N2, col="Vehicles", interval=(24)) #taking a day's diffrence
df_N2 = df_N2[24:]
df_N2.columns = ["Norm"]
df_N2["Diff"]= Diff_2

df_N3, av_J3, std_J3 = Normalize(df_3, "Vehicles")
Diff_3 = Difference(df_N3, col="Vehicles", interval=1) #taking an hour's diffrence
df_N3 = df_N3[1:]
df_N3.columns = ["Norm"]
df_N3["Diff"]= Diff_3

df_N4, av_J4, std_J4 = Normalize(df_4, "Vehicles")
Diff_4 = Difference(df_N4, col="Vehicles", interval=1) #taking an hour's diffrence
df_N4 = df_N4[1:]
df_N4.columns = ["Norm"]
df_N4["Diff"]= Diff_4

# %%
Sub_Plots4(df_N1.Diff, df_N2.Diff,df_N3.Diff,df_N4.Diff,"Dataframes After Transformation")

# %%
#Stationary Check for the time series Augmented Dickey Fuller test
def Stationary_check(df):
    check = adfuller(df.dropna())
    print(f"ADF Statistic: {check[0]}")
    print(f"p-value: {check[1]}")
    print("Critical Values:")
    for key, value in check[4].items():
        print('\t%s: %.3f' % (key, value))
    if check[0] > check[4]["1%"]:
        print("Time Series is Non-Stationary")
    else:
        print("Time Series is Stationary") 
  

#Checking if the series is stationary

List_df_ND = [ df_N1["Diff"], df_N2["Diff"], df_N3["Diff"], df_N4["Diff"]] 
print("Checking the transformed series for stationarity:")
for i in List_df_ND:
    print("\n")
    Stationary_check(i)
# Out:
# Checking the transformed series for stationarity:
#
#
# ADF Statistic: -15.265303390415493
# p-value: 4.798539876395891e-28
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -21.795891026940094
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -28.001759908832415
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -17.97909256305227
# p-value: 2.7787875325955e-30
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary

# %%
#Differencing created some NA values as we took a weeks data into consideration while difrencing
df_J1 = df_N1["Diff"].dropna()
df_J1 = df_J1.to_frame()

df_J2 = df_N2["Diff"].dropna()
df_J2 = df_J2.to_frame()

df_J3 = df_N3["Diff"].dropna()
df_J3 = df_J3.to_frame()

df_J4 = df_N4["Diff"].dropna()
df_J4 = df_J4.to_frame()

#Splitting the dataset
def Split_data(df):
    training_size = int(len(df)*0.90)
    data_len = len(df)
    train, test = df[0:training_size],df[training_size:data_len] 
    train, test = train.values.reshape(-1, 1), test.values.reshape(-1, 1)
    return train, test
#Splitting the training and test datasets 
J1_train, J1_test = Split_data(df_J1)
J2_train, J2_test = Split_data(df_J2)
J3_train, J3_test = Split_data(df_J3)
J4_train, J4_test = Split_data(df_J4)

#Target and Feature
def TnF(df):
    end_len = len(df)
    X = []
    y = []
    steps = 32
    for i in range(steps, end_len):
        X.append(df[i - steps:i, 0])
        y.append(df[i, 0])
    X, y = np.array(X), np.array(y)
    return X ,y

#fixing the shape of X_test and X_train
def FeatureFixShape(train, test):
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0],test.shape[1],1))
    return train, test

#Assigning features and target 
X_trainJ1, y_trainJ1 = TnF(J1_train)
X_testJ1, y_testJ1 = TnF(J1_test)
X_trainJ1, X_testJ1 = FeatureFixShape(X_trainJ1, X_testJ1)

X_trainJ2, y_trainJ2 = TnF(J2_train)
X_testJ2, y_testJ2 = TnF(J2_test)
X_trainJ2, X_testJ2 = FeatureFixShape(X_trainJ2, X_testJ2)

X_trainJ3, y_trainJ3 = TnF(J3_train)
X_testJ3, y_testJ3 = TnF(J3_test)
X_trainJ3, X_testJ3 = FeatureFixShape(X_trainJ3, X_testJ3)

X_trainJ4, y_trainJ4 = TnF(J4_train)
X_testJ4, y_testJ4 = TnF(J4_test)
X_trainJ4, X_testJ4 = FeatureFixShape(X_trainJ4, X_testJ4)

# %%
#Model for the prediction
def GRU_model(X_Train, y_Train, X_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True) 
    #callback delta 0.01 may interrupt the learning, could eliminate this step, but meh!
    
    #The GRU model 
    model = Sequential()
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    #model.add(GRU(units=50, return_sequences=True,  input_shape=(X_Train.shape[1],1),activation='tanh'))
    #model.add(Dropout(0.2))
    model.add(GRU(units=50, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    #Compiling the model
    model.compile(optimizer=SGD(decay=1e-7, momentum=0.9),loss='mean_squared_error')
    model.fit(X_Train,y_Train, epochs=50, batch_size=150,callbacks=[early_stopping])
    pred_GRU= model.predict(X_Test)
    return pred_GRU

#To calculate the root mean squred error in predictions
def RMSE_Value(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

#To plot the comparitive plot of targets and predictions
def PredictionsPlot(test,predicted,m):
    plt.figure(figsize=(12,5),facecolor="#627D78")
    plt.plot(test, color=colors[m],label="True Value",alpha=0.5 )
    plt.plot(predicted, color="#627D78",label="Predicted Values")
    plt.title("GRU Traffic Prediction Vs True values")
    plt.xlabel("DateTime")
    plt.ylabel("Number of Vehicles")
    plt.legend()
    plt.show()

# %%
#Predictions For First Junction
PredJ1 = GRU_model(X_trainJ1,y_trainJ1,X_testJ1)
# Out:
# Epoch 1/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0789WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 44s 403ms/step - loss: 0.0789
# Epoch 2/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0664WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 34s 390ms/step - loss: 0.0664
# Epoch 3/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0651WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 39s 447ms/step - loss: 0.0651
# Epoch 4/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0640WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 34s 387ms/step - loss: 0.0640
# Epoch 5/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0621WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 338ms/step - loss: 0.0621
# Epoch 6/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0613WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 37s 419ms/step - loss: 0.0613
# Epoch 7/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0600WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 36s 414ms/step - loss: 0.0600
# Epoch 8/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0594WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 30s 344ms/step - loss: 0.0594
# Epoch 9/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0582WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 335ms/step - loss: 0.0582
# Epoch 10/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0570WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 336ms/step - loss: 0.0570
# Epoch 11/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0570WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 335ms/step - loss: 0.0570
# Epoch 12/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0562WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 329ms/step - loss: 0.0562
# Epoch 13/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0558WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 331ms/step - loss: 0.0558
# Epoch 14/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0547WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 30s 350ms/step - loss: 0.0547
# Epoch 15/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0550WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 332ms/step - loss: 0.0550
# Epoch 16/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0539WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 330ms/step - loss: 0.0539
# Epoch 17/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0543WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 331ms/step - loss: 0.0543
# Epoch 18/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0535WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 330ms/step - loss: 0.0535
# Epoch 19/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0525WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 332ms/step - loss: 0.0525
# Epoch 20/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0525WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 331ms/step - loss: 0.0525
# Epoch 21/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0523WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 331ms/step - loss: 0.0523
# Epoch 22/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0515WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 30s 339ms/step - loss: 0.0515
# Epoch 23/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0515WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 329ms/step - loss: 0.0515
# Epoch 24/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0508WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 329ms/step - loss: 0.0508
# Epoch 25/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0514WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 328ms/step - loss: 0.0514
# Epoch 26/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0514WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 327ms/step - loss: 0.0514
# Epoch 27/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0502WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 329ms/step - loss: 0.0502
# Epoch 28/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0503WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 329ms/step - loss: 0.0503
# Epoch 29/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0500WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 330ms/step - loss: 0.0500
# Epoch 30/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0497WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 30s 340ms/step - loss: 0.0497
# Epoch 31/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0492WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 331ms/step - loss: 0.0492
# Epoch 32/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0496WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 330ms/step - loss: 0.0496
# Epoch 33/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0498WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 331ms/step - loss: 0.0498
# Epoch 34/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0492WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 329ms/step - loss: 0.0492
# Epoch 35/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0493WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 332ms/step - loss: 0.0493
# Epoch 36/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0491WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 331ms/step - loss: 0.0491
# Epoch 37/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0491WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 30s 340ms/step - loss: 0.0491
# Epoch 38/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0489WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 328ms/step - loss: 0.0489
# Epoch 39/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 330ms/step - loss: 0.0486
# Epoch 40/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0485WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 329ms/step - loss: 0.0485
# Epoch 41/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0483WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 329ms/step - loss: 0.0483
# Epoch 42/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 329ms/step - loss: 0.0482
# Epoch 43/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0479WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 331ms/step - loss: 0.0479
# Epoch 44/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 30s 343ms/step - loss: 0.0482
# Epoch 45/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0480WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 330ms/step - loss: 0.0480
# Epoch 46/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0480WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 330ms/step - loss: 0.0480
# Epoch 47/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0475WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 332ms/step - loss: 0.0475
# Epoch 48/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0476WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 331ms/step - loss: 0.0476
# Epoch 49/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0478WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 330ms/step - loss: 0.0478
# Epoch 50/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0478WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 330ms/step - loss: 0.0478

# %%
#Results for J1 
RMSE_J1=RMSE_Value(y_testJ1,PredJ1)
PredictionsPlot(y_testJ1,PredJ1,0)
# Out:
# The root mean squared error is 0.24572463987140264.

# %%
#Predictions For Second Junction
PredJ2 = GRU_model(X_trainJ2,y_trainJ2,X_testJ2)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2348WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 38s 335ms/step - loss: 0.2348
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2026WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 344ms/step - loss: 0.2026
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1982WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 332ms/step - loss: 0.1982
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1964WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 332ms/step - loss: 0.1964
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1930WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 334ms/step - loss: 0.1930
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1903WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.1903
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1906WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.1906
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1931WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 335ms/step - loss: 0.1931
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1899WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 345ms/step - loss: 0.1899
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1877WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 336ms/step - loss: 0.1877
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1873WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 333ms/step - loss: 0.1873
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 334ms/step - loss: 0.1871
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 333ms/step - loss: 0.1888
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1880WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 333ms/step - loss: 0.1880
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1863WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 333ms/step - loss: 0.1863
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1874WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 345ms/step - loss: 0.1874
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1869WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 333ms/step - loss: 0.1869
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1851WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 333ms/step - loss: 0.1851
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1849WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 334ms/step - loss: 0.1849
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1843WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 336ms/step - loss: 0.1843
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1849WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 337ms/step - loss: 0.1849
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1835WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 334ms/step - loss: 0.1835
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1842WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 345ms/step - loss: 0.1842
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1844WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 333ms/step - loss: 0.1844
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1840WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 333ms/step - loss: 0.1840
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1835WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 335ms/step - loss: 0.1835
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1839WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 335ms/step - loss: 0.1839
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1827WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 335ms/step - loss: 0.1827
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1838WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 336ms/step - loss: 0.1838
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1829WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 31s 347ms/step - loss: 0.1829
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1841WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 335ms/step - loss: 0.1841
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 333ms/step - loss: 0.1828
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 335ms/step - loss: 0.1828
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 335ms/step - loss: 0.1828
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 333ms/step - loss: 0.1816
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1819WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 335ms/step - loss: 0.1819
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1838WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 31s 353ms/step - loss: 0.1838
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1827WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 335ms/step - loss: 0.1827
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1818WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 336ms/step - loss: 0.1818
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1826WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 336ms/step - loss: 0.1826
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1825WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 334ms/step - loss: 0.1825
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 335ms/step - loss: 0.1812
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1815WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 336ms/step - loss: 0.1815
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1820WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 336ms/step - loss: 0.1820
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1817WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 31s 347ms/step - loss: 0.1817
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1814WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 335ms/step - loss: 0.1814
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1815WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 335ms/step - loss: 0.1815
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1819WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.1819
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1822WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.1822
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1811WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 337ms/step - loss: 0.1811

# %%
#Results for J2
RMSE_J2=RMSE_Value(y_testJ2,PredJ2)
PredictionsPlot(y_testJ2,PredJ2,1)
# Out:
# The root mean squared error is 0.556401417639558.

# %%
#Predictions For Third Junction
PredJ3 = GRU_model(X_trainJ3,y_trainJ3,X_testJ3)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.3010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 39s 338ms/step - loss: 0.3010
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2968WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 337ms/step - loss: 0.2968
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2924WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2924
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2899WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2899
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 340ms/step - loss: 0.2882
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.2886
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2885WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 31s 348ms/step - loss: 0.2885
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.2871
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2866WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.2866
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2892WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 340ms/step - loss: 0.2892
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2840WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.2840
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2840WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2840
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2863WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2863
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2824WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 31s 349ms/step - loss: 0.2824
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2811WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 337ms/step - loss: 0.2811
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2794WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2794
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2785WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.2785
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2785WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.2785
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2766WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2766
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2826WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2826
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2740WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.2740
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2710WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 31s 349ms/step - loss: 0.2710
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2725WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2725
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2732WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2732
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2712WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 337ms/step - loss: 0.2712
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2729WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 336ms/step - loss: 0.2729
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2741WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2741
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2706WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2706
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2724WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 31s 348ms/step - loss: 0.2724
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2708WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 340ms/step - loss: 0.2708
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2704WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2704
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2708WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.2708
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2707WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.2707
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2722WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.2722
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2697WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2697
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2706WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 31s 350ms/step - loss: 0.2706
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2700WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.2700
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2702WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 337ms/step - loss: 0.2702
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2688
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2672WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2672
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2699WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2699
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2664WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2664
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2670WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2670
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2667WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 31s 347ms/step - loss: 0.2667
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2689WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2689
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2651WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 337ms/step - loss: 0.2651
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2645WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2645
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2651WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 337ms/step - loss: 0.2651
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2670WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 339ms/step - loss: 0.2670
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2652WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 338ms/step - loss: 0.2652

# %%
#Results for J3
RMSE_J3=RMSE_Value(y_testJ3,PredJ3)
PredictionsPlot(y_testJ3,PredJ3,2)
# Out:
# The root mean squared error is 0.6068279303301265.

# %%
#Predictions For Forth Junction
PredJ4 = GRU_model(X_trainJ4,y_trainJ4,X_testJ4)
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6917WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 18s 341ms/step - loss: 0.6917
# Epoch 2/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6926WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 333ms/step - loss: 0.6926
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6905WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 335ms/step - loss: 0.6905
# Epoch 4/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6852WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 336ms/step - loss: 0.6852
# Epoch 5/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6824WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 334ms/step - loss: 0.6824
# Epoch 6/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6929WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 333ms/step - loss: 0.6929
# Epoch 7/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6814WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 335ms/step - loss: 0.6814
# Epoch 8/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6813WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 333ms/step - loss: 0.6813
# Epoch 9/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6864WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 334ms/step - loss: 0.6864
# Epoch 10/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6778WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 331ms/step - loss: 0.6778
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6769WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 332ms/step - loss: 0.6769
# Epoch 12/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6758WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 334ms/step - loss: 0.6758
# Epoch 13/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6766WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 331ms/step - loss: 0.6766
# Epoch 14/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6779WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 332ms/step - loss: 0.6779
# Epoch 15/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6758WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 331ms/step - loss: 0.6758
# Epoch 16/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6738WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 333ms/step - loss: 0.6738
# Epoch 17/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6759WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 331ms/step - loss: 0.6759
# Epoch 18/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6738WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 332ms/step - loss: 0.6738
# Epoch 19/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6825WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 332ms/step - loss: 0.6825
# Epoch 20/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6732WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 336ms/step - loss: 0.6732
# Epoch 21/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6726WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 339ms/step - loss: 0.6726
# Epoch 22/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6798WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 333ms/step - loss: 0.6798
# Epoch 23/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6692WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 337ms/step - loss: 0.6692
# Epoch 24/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6719WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 348ms/step - loss: 0.6719
# Epoch 25/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6735WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 336ms/step - loss: 0.6735
# Epoch 26/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6701WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 333ms/step - loss: 0.6701
# Epoch 27/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 335ms/step - loss: 0.6688
# Epoch 28/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6617WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 333ms/step - loss: 0.6617
# Epoch 29/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6624WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 335ms/step - loss: 0.6624
# Epoch 30/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6616WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 338ms/step - loss: 0.6616
# Epoch 31/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6560WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 333ms/step - loss: 0.6560
# Epoch 32/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6625WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 338ms/step - loss: 0.6625
# Epoch 33/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6575WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 334ms/step - loss: 0.6575
# Epoch 34/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6456WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 336ms/step - loss: 0.6456
# Epoch 35/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6446WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 334ms/step - loss: 0.6446
# Epoch 36/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6310WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 336ms/step - loss: 0.6310
# Epoch 37/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6354WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 334ms/step - loss: 0.6354
# Epoch 38/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 336ms/step - loss: 0.6375
# Epoch 39/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6335WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 338ms/step - loss: 0.6335
# Epoch 40/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6119WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 335ms/step - loss: 0.6119
# Epoch 41/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6005WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 333ms/step - loss: 0.6005
# Epoch 42/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6001WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 336ms/step - loss: 0.6001
# Epoch 43/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 335ms/step - loss: 0.6000
# Epoch 44/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5873WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 334ms/step - loss: 0.5873
# Epoch 45/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5694WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 336ms/step - loss: 0.5694
# Epoch 46/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5645WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 337ms/step - loss: 0.5645
# Epoch 47/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5528WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 337ms/step - loss: 0.5528
# Epoch 48/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5505WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 340ms/step - loss: 0.5505
# Epoch 49/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5497WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 361ms/step - loss: 0.5497
# Epoch 50/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5343WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 338ms/step - loss: 0.5343

# %%
#Results for J4
RMSE_J4=RMSE_Value(y_testJ4,PredJ4)
PredictionsPlot(y_testJ4,PredJ4,3)
# Out:
# The root mean squared error is 0.9976003044641727.

# %%
# Functions to inverse transforms and Plot comparitive plots
# invert differenced forecast
def inverse_difference(last_ob, value):
    inversed = value + last_ob
    return inversed
#Plotting the comparison
def Sub_Plots2(df_1, df_2,title,m):
    fig, axes = plt.subplots(1, 2, figsize=(18,4), sharey=True,facecolor="#627D78")
    fig.suptitle(title)
    
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[m])
    axes[0].set(ylabel ="Prediction")
    
    pl_2=sns.lineplot(ax=axes[1],data=df_2["Vehicles"],color="#627D78")
    axes[1].set(ylabel ="Orignal")

# %%
# invert the differenced forecast for Junction 1 
recover1 = df_N1.Norm[-1412:-1].to_frame()
recover1["Pred"]= PredJ1
Transform_reverssed_J1 = inverse_difference(recover1.Norm, recover1.Pred).to_frame()
Transform_reverssed_J1.columns = ["Pred_Normed"]
#Invert the normalizeation J1
Final_J1_Pred = (Transform_reverssed_J1.values* std_J1) + av_J1
Transform_reverssed_J1["Pred_Final"] =Final_J1_Pred
#Plotting the Predictions with orignals 
Sub_Plots2(Transform_reverssed_J1["Pred_Final"], df_1[-1412:-1],"Pridictions And Orignals For Junction 1", 0)

# %%
#Invert the differenced J2
recover2 = df_N2.Norm[-1426:-1].to_frame() #len as per the diff
recover2["Pred"]= PredJ2
Transform_reverssed_J2 = inverse_difference(recover2.Norm, recover2.Pred).to_frame()
Transform_reverssed_J2.columns = ["Pred_Normed"]
Final_J2_Pred = (Transform_reverssed_J2.values* std_J2) + av_J2
Transform_reverssed_J2["Pred_Final"] =Final_J2_Pred
#Plotting the Predictions with orignals 
Sub_Plots2(Transform_reverssed_J2["Pred_Final"], df_2[-1426:-1],"Pridictions And Orignals For Junction 2", 1)

# %%
#Invert the differenced J3
recover3 = df_N3.Norm[-1429:-1].to_frame() #len as per the diff
recover3["Pred"]= PredJ3
Transform_reverssed_J3 = inverse_difference(recover3.Norm, recover3.Pred).to_frame()
Transform_reverssed_J3.columns = ["Pred_Normed"]
#Invert the normalizeation J3
Final_J3_Pred = (Transform_reverssed_J3.values* std_J3) + av_J3
Transform_reverssed_J3["Pred_Final"] =Final_J3_Pred
Sub_Plots2(Transform_reverssed_J3["Pred_Final"], df_3[-1429:-1],"Pridictions And Orignals For Junction 3", 2)

# %%
#Invert the differenced J4
recover4 = df_N4.Norm[-404:-1].to_frame()  #len as per the testset
recover4["Pred"]= PredJ4
Transform_reverssed_J4 = inverse_difference(recover4.Norm, recover4.Pred).to_frame()
Transform_reverssed_J4.columns = ["Pred_Normed"]
#Invert the normalizeation J4
Final_J4_Pred = (Transform_reverssed_J4.values* std_J4) + av_J4
Transform_reverssed_J4["Pred_Final"] =Final_J4_Pred
Sub_Plots2(Transform_reverssed_J4["Pred_Final"], df_4[-404:-1],"Pridictions And Orignals For Junction 4", 3)
